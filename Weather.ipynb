# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city based on latitude and longitude coordinates
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #if the city is unique then we will add it to the list
    if city not in cities:
        cities.append(city)

#print the city count to ensure we have enough cities
len(cities)
# Out:
# 612

# %%
#Pseudocode
#Import dependencies and initialize counters and an empty list to hold weather data
# Loop through the cities list
# group the cities into sets of 50 to log the process as we find the weather data for each city
    # Two counters will be needed here: one to log the city count from 1 to 50, another for the sets
# Build the city_url or endpoint for each city
# log the URL and the record and set number
# make an API request for each city
# parse the JSON weather data for the following: City, country, date, lat, lng, max temp, humidity, clouds, wind
# add the data to a list in dictionary format and conver the list to a dataframe

# %%
# import requests library and api key
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the dteimte library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging.
print('Beginning Data Retrieval     ')
print('_____________________________')
# create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# _____________________________

# %%
# Loop through all the cities in our list
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create the endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities
# include tryand except blocks
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        #Country
        city_country = city_weather['sys']['country']
        #Latitude
        city_lat = city_weather['coord']['lat']
        #Longitude
        city_lng = city_weather['coord']['lon']
        # Max temp
        city_max_temp = city_weather['main']['temp_max']
        # humidity
        city_humidity = city_weather['main']['humidity']
        # cloudiness
        city_clouds = city_weather['clouds']['all']
        # wind speed
        city_wind = city_weather['wind']['speed']
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime("%Y-%m-%d %H:%M:%S")
        # Append city information to a city_data list
        city_data.append({"City": city.title(),
                          "Lat":city_lat,
                          "Lng":city_lng,
                          "Max Temp":city_max_temp,
                          "Humidity":city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# if an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is Complete.
print("-------------------------")
print("Data Retrieval Complete. ")
print("-------------------------")
# Out:
# Processing Record 13 of Set 13 | tuatapere
# Processing Record 14 of Set 13 | yellowknife
# Processing Record 15 of Set 13 | alofi
# Processing Record 16 of Set 13 | manado
# Processing Record 17 of Set 13 | oranjemund
# Processing Record 18 of Set 13 | bambanglipuro
# Processing Record 19 of Set 13 | danville
# Processing Record 20 of Set 13 | faanui
# Processing Record 21 of Set 13 | biltine
# Processing Record 22 of Set 13 | punta arenas
# Processing Record 23 of Set 13 | broome
# Processing Record 24 of Set 13 | nishihara
# Processing Record 25 of Set 13 | asyut
# Processing Record 26 of Set 13 | guerrero negro
# Processing Record 27 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 28 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 13 | cidreira
# Processing Record 30 of Set 13 | grand gaube
# Processing Record 31 of Set 13 | hobart
# Processing Record 32 of Set 13 | bredasdorp
# Processing Record 33 of Set 13 | ahipara
# Processing Record 34 of Set 13 | cuamba
# Processing Record 35 of Set 13 | dikson
# Processing Record 36 of Set 13 | bluff
# Processing Record 37 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 13 | coihaique
# Processing Record 39 of Set 13 | los llanos de aridane
# Processing Record 40 of Set 13 | saint-augustin
# Processing Record 41 of Set 13 | tasiilaq
# Processing Record 42 of Set 13 | khatanga
# Processing Record 43 of Set 13 | talgar
# Processing Record 44 of Set 13 | port elizabeth
# Processing Record 45 of Set 13 | mabaruma
# Processing Record 46 of Set 13 | hobyo
# Processing Record 47 of Set 13 | albany
# Processing Record 48 of Set 13 | nanortalik
# Processing Record 49 of Set 13 | osinki
# Processing Record 50 of Set 13 | vao
# Processing Record 51 of Set 13 | tabou
# Processing Record 52 of Set 13 | jamestown
# Processing Record 53 of Set 13 | cherskiy
# Processing Record 54 of Set 13 | sabancuy
# Processing Record 55 of Set 13 | praia
# Processing Record 56 of Set 13 | kaitangata
# Processing Record 57 of Set 13 | guaruja
# Processing Record 58 of Set 13 | chokurdakh
# Processing Record 59 of Set 13 | severo-kurilsk
# Processing Record 60 of Set 13 | winnemucca
# Processing Record 61 of Set 13 | ancud
# Processing Record 62 of Set 13 | atuona
# Processing Record 1 of Set 14 | mana
# Processing Record 2 of Set 14 | carnarvon
# Processing Record 3 of Set 14 | sinnamary
# Processing Record 4 of Set 14 | arraial do cabo
# Processing Record 5 of Set 14 | vaini
# Processing Record 6 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 14 | adrar
# Processing Record 8 of Set 14 | te anau
# Processing Record 9 of Set 14 | manggar
# Processing Record 10 of Set 14 | cabral
# Processing Record 11 of Set 14 | cape town
# Processing Record 12 of Set 14 | lasa
# Processing Record 13 of Set 14 | ushuaia
# Processing Record 14 of Set 14 | isangel
# Processing Record 15 of Set 14 | quatre cocos
# Processing Record 16 of Set 14 | rikitea
# Processing Record 17 of Set 14 | san cristobal
# Processing Record 18 of Set 14 | busselton
# Processing Record 19 of Set 14 | puerto ayora
# Processing Record 20 of Set 14 | bilokurakyne
# Processing Record 21 of Set 14 | geraldton
# Processing Record 22 of Set 14 | airai
# Processing Record 23 of Set 14 | belaya gora
# Processing Record 24 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 14 | ketchikan
# Processing Record 27 of Set 14 | qaanaaq
# Processing Record 28 of Set 14 | viedma
# Processing Record 29 of Set 14 | kastellion
# City not found. Skipping...
# Processing Record 30 of Set 14 | port lincoln
# Processing Record 31 of Set 14 | kruisfontein
# Processing Record 32 of Set 14 | urusha
# Processing Record 33 of Set 14 | hilo
# Processing Record 34 of Set 14 | salta
# Processing Record 35 of Set 14 | fort nelson
# Processing Record 36 of Set 14 | aykhal
# Processing Record 37 of Set 14 | guarapari
# Processing Record 38 of Set 14 | kouango
# Processing Record 39 of Set 14 | new norfolk
# Processing Record 40 of Set 14 | talaja
# Processing Record 41 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 14 | antofagasta
# Processing Record 43 of Set 14 | nokha
# Processing Record 44 of Set 14 | ixtapa
# Processing Record 45 of Set 14 | shingu
# Processing Record 46 of Set 14 | abha
# Processing Record 47 of Set 14 | sabang
# Processing Record 48 of Set 14 | ribeira grande
# Processing Record 49 of Set 14 | bethanien
# Processing Record 50 of Set 14 | luwuk
# Processing Record 1 of Set 15 | nikolskoye
# Processing Record 2 of Set 15 | nuuk
# Processing Record 3 of Set 15 | natal
# Processing Record 4 of Set 15 | aquin
# Processing Record 5 of Set 15 | kapaa
# Processing Record 6 of Set 15 | marawi
# Processing Record 7 of Set 15 | flinders
# Processing Record 8 of Set 15 | kiruna
# Processing Record 9 of Set 15 | ugoofaaru
# Processing Record 10 of Set 15 | mahebourg
# Processing Record 11 of Set 15 | mlalo
# Processing Record 12 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 15 | camopi
# Processing Record 14 of Set 15 | pedregulho
# Processing Record 15 of Set 15 | saskylakh
# Processing Record 16 of Set 15 | constitucion
# Processing Record 17 of Set 15 | east london
# Processing Record 18 of Set 15 | bambous virieux
# Processing Record 19 of Set 15 | pedra azul
# Processing Record 20 of Set 15 | itarema
# Processing Record 21 of Set 15 | tigzirt
# Processing Record 22 of Set 15 | touros
# Processing Record 23 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 15 | apatity
# Processing Record 25 of Set 15 | kampong thum
# Processing Record 26 of Set 15 | umm kaddadah
# Processing Record 27 of Set 15 | souillac
# Processing Record 28 of Set 15 | georgetown
# Processing Record 29 of Set 15 | butaritari
# Processing Record 30 of Set 15 | coos bay
# Processing Record 31 of Set 15 | bathsheba
# Processing Record 32 of Set 15 | san patricio
# Processing Record 33 of Set 15 | bethel
# Processing Record 34 of Set 15 | avarua
# Processing Record 35 of Set 15 | pevek
# Processing Record 36 of Set 15 | upernavik
# Processing Record 37 of Set 15 | rovaniemi
# Processing Record 38 of Set 15 | rawson
# Processing Record 39 of Set 15 | moron
# Processing Record 40 of Set 15 | vodnyy
# Processing Record 41 of Set 15 | coquimbo
# Processing Record 42 of Set 15 | zhob
# Processing Record 43 of Set 15 | boat of garten
# Processing Record 44 of Set 15 | honiara
# Processing Record 45 of Set 15 | alice springs
# Processing Record 46 of Set 15 | victoria
# Processing Record 47 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 15 | arys
# Processing Record 49 of Set 15 | aksarka
# Processing Record 50 of Set 15 | maksatikha
# Processing Record 1 of Set 16 | vila velha
# Processing Record 2 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 16 | maragogi
# Processing Record 4 of Set 16 | narsaq
# Processing Record 5 of Set 16 | rocha
# Processing Record 6 of Set 16 | horsham
# Processing Record 7 of Set 16 | vila franca do campo
# Processing Record 8 of Set 16 | longyearbyen
# Processing Record 9 of Set 16 | kanashevo
# Processing Record 10 of Set 16 | thompson
# Processing Record 11 of Set 16 | ginda
# Processing Record 12 of Set 16 | maniwaki
# Processing Record 13 of Set 16 | aranos
# Processing Record 14 of Set 16 | mutis
# Processing Record 15 of Set 16 | mae sai
# Processing Record 16 of Set 16 | warangal
# Processing Record 17 of Set 16 | kodiak
# Processing Record 18 of Set 16 | fomboni
# Processing Record 19 of Set 16 | mongo
# Processing Record 20 of Set 16 | tame
# Processing Record 21 of Set 16 | dungarpur
# Processing Record 22 of Set 16 | rusape
# Processing Record 23 of Set 16 | jiaohe
# Processing Record 24 of Set 16 | tawnat
# City not found. Skipping...
# Processing Record 25 of Set 16 | gopalpur
# Processing Record 26 of Set 16 | krasnyy chikoy
# Processing Record 27 of Set 16 | naze
# Processing Record 28 of Set 16 | sao geraldo do araguaia
# Processing Record 29 of Set 16 | fare
# Processing Record 30 of Set 16 | oktyabrskiy
# Processing Record 31 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 16 | gravdal
# Processing Record 33 of Set 16 | concepcion del oro
# Processing Record 34 of Set 16 | tripoli
# Processing Record 35 of Set 16 | zhuzhou
# Processing Record 36 of Set 16 | saint-philippe
# Processing Record 37 of Set 16 | pangkalanbuun
# Processing Record 38 of Set 16 | imuris
# Processing Record 39 of Set 16 | le port
# Processing Record 40 of Set 16 | hithadhoo
# Processing Record 41 of Set 16 | naryan-mar
# Processing Record 42 of Set 16 | mehamn
# Processing Record 43 of Set 16 | northam
# Processing Record 44 of Set 16 | codrington
# Processing Record 45 of Set 16 | chimbote
# Processing Record 46 of Set 16 | kemin
# Processing Record 47 of Set 16 | port alfred
# Processing Record 48 of Set 16 | aklavik
# Processing Record 49 of Set 16 | bayan
# Processing Record 50 of Set 16 | mount isa
# Processing Record 1 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 17 | monatele
# City not found. Skipping...
# Processing Record 3 of Set 17 | qurayyat
# Processing Record 4 of Set 17 | hualmay
# Processing Record 5 of Set 17 | mataura
# Processing Record 6 of Set 17 | el campo
# Processing Record 7 of Set 17 | kieta
# Processing Record 8 of Set 17 | saint anthony
# Processing Record 9 of Set 17 | mackenzie
# Processing Record 10 of Set 17 | sitka
# Processing Record 11 of Set 17 | leningradskiy
# Processing Record 12 of Set 17 | kavieng
# Processing Record 13 of Set 17 | horizonte
# Processing Record 14 of Set 17 | acajutla
# Processing Record 15 of Set 17 | la cumbre
# Processing Record 16 of Set 17 | beringovskiy
# Processing Record 17 of Set 17 | hasaki
# Processing Record 18 of Set 17 | saldanha
# Processing Record 19 of Set 17 | verkhnyaya inta
# Processing Record 20 of Set 17 | lagoa
# Processing Record 21 of Set 17 | vardo
# Processing Record 22 of Set 17 | ambon
# Processing Record 23 of Set 17 | kaa-khem
# Processing Record 24 of Set 17 | higueron
# Processing Record 25 of Set 17 | svetlogorsk
# Processing Record 26 of Set 17 | flagstaff
# Processing Record 27 of Set 17 | padang
# Processing Record 28 of Set 17 | barrow
# Processing Record 29 of Set 17 | tiksi
# Processing Record 30 of Set 17 | yirol
# City not found. Skipping...
# Processing Record 31 of Set 17 | harindanga
# Processing Record 32 of Set 17 | sukhovolya
# Processing Record 33 of Set 17 | pangai
# Processing Record 34 of Set 17 | isiro
# Processing Record 35 of Set 17 | sangar
# Processing Record 36 of Set 17 | moss vale
# Processing Record 37 of Set 17 | noshiro
# Processing Record 38 of Set 17 | brae
# Processing Record 39 of Set 17 | tuktoyaktuk
# Processing Record 40 of Set 17 | methoni
# Processing Record 41 of Set 17 | omboue
# Processing Record 42 of Set 17 | baykit
# Processing Record 43 of Set 17 | anuradhapura
# Processing Record 44 of Set 17 | panguipulli
# Processing Record 45 of Set 17 | tubuala
# Processing Record 46 of Set 17 | ryotsu
# Processing Record 47 of Set 17 | lincoln
# Processing Record 48 of Set 17 | merrill
# Processing Record 49 of Set 17 | mill valley
# Processing Record 50 of Set 17 | shakhunya
# Processing Record 1 of Set 18 | the valley
# Processing Record 2 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 18 | makakilo city
# Processing Record 4 of Set 18 | hermanus
# Processing Record 5 of Set 18 | mar del plata
# Processing Record 6 of Set 18 | santa clara
# Processing Record 7 of Set 18 | mount gambier
# Processing Record 8 of Set 18 | cibitoke
# Processing Record 9 of Set 18 | shirgaon
# Processing Record 10 of Set 18 | talnakh
# Processing Record 11 of Set 18 | college
# Processing Record 12 of Set 18 | dunedin
# Processing Record 13 of Set 18 | monywa
# Processing Record 14 of Set 18 | castro
# Processing Record 15 of Set 18 | batticaloa
# Processing Record 16 of Set 18 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 18 | kandrian
# Processing Record 18 of Set 18 | thinadhoo
# Processing Record 19 of Set 18 | seoul
# Processing Record 20 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 18 | caxito
# Processing Record 22 of Set 18 | tilichiki
# Processing Record 23 of Set 18 | west bay
# Processing Record 24 of Set 18 | gasa
# Processing Record 25 of Set 18 | mudgee
# Processing Record 26 of Set 18 | plover
# Processing Record 27 of Set 18 | staraya poltavka
# Processing Record 28 of Set 18 | demyansk
# Processing Record 29 of Set 18 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 18 | kytlym
# City not found. Skipping...
# Processing Record 31 of Set 18 | qasigiannguit
# Processing Record 32 of Set 18 | sivas
# Processing Record 33 of Set 18 | namatanai
# Processing Record 34 of Set 18 | clyde river
# Processing Record 35 of Set 18 | sibolga
# Processing Record 36 of Set 18 | chuy
# Processing Record 37 of Set 18 | harper
# Processing Record 38 of Set 18 | sao sebastiao
# Processing Record 39 of Set 18 | zabol
# Processing Record 40 of Set 18 | mayo
# Processing Record 41 of Set 18 | karratha
# Processing Record 42 of Set 18 | banepa
# Processing Record 43 of Set 18 | grand-lahou
# Processing Record 44 of Set 18 | yandoon
# City not found. Skipping...
# Processing Record 45 of Set 18 | nouadhibou
# Processing Record 46 of Set 18 | husavik
# Processing Record 47 of Set 18 | coyuca
# City not found. Skipping...
# Processing Record 48 of Set 18 | hot springs
# Processing Record 49 of Set 18 | paros
# Processing Record 50 of Set 18 | evanston
# Processing Record 1 of Set 19 | road town
# Processing Record 2 of Set 19 | sembakung
# Processing Record 3 of Set 19 | conceicao do araguaia
# Processing Record 4 of Set 19 | esperance
# Processing Record 5 of Set 19 | jibuti
# Processing Record 6 of Set 19 | komsomolskiy
# Processing Record 7 of Set 19 | beipiao
# Processing Record 8 of Set 19 | porto velho
# Processing Record 9 of Set 19 | alta floresta
# Processing Record 10 of Set 19 | provideniya
# Processing Record 11 of Set 19 | zvishavane
# Processing Record 12 of Set 19 | balabac
# Processing Record 13 of Set 19 | srednekolymsk
# Processing Record 14 of Set 19 | silistea crucii
# Processing Record 15 of Set 19 | lagoa vermelha
# Processing Record 16 of Set 19 | haines junction
# Processing Record 17 of Set 19 | yarovoye
# Processing Record 18 of Set 19 | lata
# Processing Record 19 of Set 19 | trairi
# Processing Record 20 of Set 19 | dauphin
# Processing Record 21 of Set 19 | kahului
# Processing Record 22 of Set 19 | bud
# Processing Record 23 of Set 19 | zaozhuang
# Processing Record 24 of Set 19 | bulungu
# Processing Record 25 of Set 19 | ljungby
# Processing Record 26 of Set 19 | korla
# Processing Record 27 of Set 19 | ahumada
# City not found. Skipping...
# Processing Record 28 of Set 19 | ilulissat
# Processing Record 29 of Set 19 | araouane
# Processing Record 30 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 19 | carahue
# Processing Record 32 of Set 19 | bonavista
# Processing Record 33 of Set 19 | homer
# Processing Record 34 of Set 19 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 19 | lerwick
# Processing Record 36 of Set 19 | leshukonskoye
# Processing Record 37 of Set 19 | aasiaat
# Processing Record 38 of Set 19 | general roca
# Processing Record 39 of Set 19 | iqaluit
# Processing Record 40 of Set 19 | azimur
# City not found. Skipping...
# Processing Record 41 of Set 19 | shimoda
# Processing Record 42 of Set 19 | cabo san lucas
# Processing Record 43 of Set 19 | kendari
# Processing Record 44 of Set 19 | mwene-ditu
# Processing Record 45 of Set 19 | atalaia
# Processing Record 46 of Set 19 | cap malheureux
# Processing Record 47 of Set 19 | san quintin
# Processing Record 48 of Set 19 | chumikan
# Processing Record 49 of Set 19 | prince rupert
# Processing Record 50 of Set 19 | norman wells
# Processing Record 1 of Set 20 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 20 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 20 | fort dodge
# Processing Record 4 of Set 20 | bela cruz
# Processing Record 5 of Set 20 | dingle
# Processing Record 6 of Set 20 | uwayl
# City not found. Skipping...
# Processing Record 7 of Set 20 | abu dhabi
# Processing Record 8 of Set 20 | fortuna
# Processing Record 9 of Set 20 | resistencia
# Processing Record 10 of Set 20 | port blair
# Processing Record 11 of Set 20 | urumqi
# Processing Record 12 of Set 20 | zaysan
# Processing Record 13 of Set 20 | mtwara
# Processing Record 14 of Set 20 | tumen
# Processing Record 15 of Set 20 | changli
# Processing Record 16 of Set 20 | sucua
# Processing Record 17 of Set 20 | gamba
# Processing Record 18 of Set 20 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 20 | ahuimanu
# Processing Record 20 of Set 20 | namibe
# Processing Record 21 of Set 20 | yaan
# Processing Record 22 of Set 20 | ipswich
# Processing Record 23 of Set 20 | san miguel
# Processing Record 24 of Set 20 | bengkulu
# Processing Record 25 of Set 20 | nome
# Processing Record 26 of Set 20 | lekoni
# Processing Record 27 of Set 20 | muroto
# Processing Record 28 of Set 20 | rio gallegos
# Processing Record 29 of Set 20 | cockburn town
# Processing Record 30 of Set 20 | phetchabun
# Processing Record 31 of Set 20 | lebu
# Processing Record 32 of Set 20 | seka
# Processing Record 33 of Set 20 | ponta do sol
# Processing Record 34 of Set 20 | choma
# Processing Record 35 of Set 20 | aranda de duero
# Processing Record 36 of Set 20 | yamada
# Processing Record 37 of Set 20 | sorong
# Processing Record 38 of Set 20 | qrendi
# Processing Record 39 of Set 20 | babanusah
# City not found. Skipping...
# Processing Record 40 of Set 20 | wellington
# Processing Record 41 of Set 20 | joacaba
# Processing Record 42 of Set 20 | dzhebariki-khaya
# Processing Record 43 of Set 20 | waddan
# Processing Record 44 of Set 20 | navapur
# City not found. Skipping...
# Processing Record 45 of Set 20 | ostrovnoy
# Processing Record 46 of Set 20 | corowa
# Processing Record 47 of Set 20 | kampot
# Processing Record 48 of Set 20 | acapulco
# Processing Record 49 of Set 20 | yeniseysk
# Processing Record 50 of Set 20 | katsuura
# Processing Record 1 of Set 21 | mnogovershinnyy
# Processing Record 2 of Set 21 | klaksvik
# Processing Record 3 of Set 21 | pijijiapan
# Processing Record 4 of Set 21 | ubatuba
# Processing Record 5 of Set 21 | huilong
# Processing Record 6 of Set 21 | pisco
# Processing Record 7 of Set 21 | port macquarie
# Processing Record 8 of Set 21 | kamennogorsk
# Processing Record 9 of Set 21 | ballina
# Processing Record 10 of Set 21 | bataipora
# Processing Record 11 of Set 21 | sibu
# Processing Record 12 of Set 21 | boyolangu
# Processing Record 13 of Set 21 | neiafu
# Processing Record 14 of Set 21 | pangnirtung
# Processing Record 15 of Set 21 | laguna
# Processing Record 16 of Set 21 | olafsvik
# Processing Record 17 of Set 21 | azanka
# Processing Record 18 of Set 21 | salalah
# Processing Record 19 of Set 21 | ulladulla
# Processing Record 20 of Set 21 | ravar
# Processing Record 21 of Set 21 | saint-francois
# Processing Record 22 of Set 21 | vostok
# Processing Record 23 of Set 21 | poum
# Processing Record 24 of Set 21 | vanavara
# Processing Record 25 of Set 21 | mecca
# Processing Record 26 of Set 21 | santiago de cao
# Processing Record 27 of Set 21 | port-cartier
# Processing Record 28 of Set 21 | kavaratti
# Processing Record 29 of Set 21 | mareeba
# Processing Record 30 of Set 21 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 21 | dzilam gonzalez
# Processing Record 32 of Set 21 | luderitz
# Processing Record 33 of Set 21 | moindou
# Processing Record 34 of Set 21 | krasnoselkup
# Processing Record 35 of Set 21 | da nang
# Processing Record 36 of Set 21 | san rafael
# Processing Record 37 of Set 21 | dejen
# Processing Record 38 of Set 21 | denpasar
# Processing Record 39 of Set 21 | ambikapur
# Processing Record 40 of Set 21 | abadiania
# Processing Record 41 of Set 21 | acarau
# Processing Record 42 of Set 21 | qaqortoq
# Processing Record 43 of Set 21 | roald
# Processing Record 44 of Set 21 | half moon bay
# Processing Record 45 of Set 21 | les escoumins
# Processing Record 46 of Set 21 | barra
# Processing Record 47 of Set 21 | collie
# Processing Record 48 of Set 21 | alugan
# Processing Record 49 of Set 21 | xining
# Processing Record 50 of Set 21 | caravelas
# Processing Record 1 of Set 22 | skanevik
# City not found. Skipping...
# Processing Record 2 of Set 22 | alihe
# Processing Record 3 of Set 22 | bilibino
# Processing Record 4 of Set 22 | colquechaca
# Processing Record 5 of Set 22 | tikhmenevo
# City not found. Skipping...
# Processing Record 6 of Set 22 | cayenne
# Processing Record 7 of Set 22 | namwala
# Processing Record 8 of Set 22 | makung
# City not found. Skipping...
# Processing Record 9 of Set 22 | olinda
# Processing Record 10 of Set 22 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 22 | la cruz
# Processing Record 12 of Set 22 | zhangye
# Processing Record 13 of Set 22 | san carlos de bariloche
# Processing Record 14 of Set 22 | okhotsk
# Processing Record 15 of Set 22 | osorio
# Processing Record 16 of Set 22 | krasnaya gora
# Processing Record 17 of Set 22 | morondava
# Processing Record 18 of Set 22 | hambantota
# Processing Record 19 of Set 22 | sulphur
# Processing Record 20 of Set 22 | atherton
# Processing Record 21 of Set 22 | nijar
# Processing Record 22 of Set 22 | amboasary
# Processing Record 23 of Set 22 | ust-nera
# Processing Record 24 of Set 22 | hofn
# Processing Record 25 of Set 22 | nangomba
# Processing Record 26 of Set 22 | soyo
# Processing Record 27 of Set 22 | aketi
# Processing Record 28 of Set 22 | safwah
# City not found. Skipping...
# Processing Record 29 of Set 22 | arsikere
# Processing Record 30 of Set 22 | yulara
# Processing Record 31 of Set 22 | manokwari
# Processing Record 32 of Set 22 | tatawin
# Processing Record 33 of Set 22 | gobabis
# Processing Record 34 of Set 22 | okha
# Processing Record 35 of Set 22 | atlantic city
# Processing Record 36 of Set 22 | comodoro rivadavia
# Processing Record 37 of Set 22 | kajaani
# Processing Record 38 of Set 22 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 22 | tari
# Processing Record 40 of Set 22 | bonthe
# Processing Record 41 of Set 22 | channel-port aux basques
# Processing Record 42 of Set 22 | floriano
# Processing Record 43 of Set 22 | pafos
# Processing Record 44 of Set 22 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 22 | adra
# Processing Record 46 of Set 22 | muros
# Processing Record 47 of Set 22 | bay saint louis
# Processing Record 48 of Set 22 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 22 | lazurne
# Processing Record 50 of Set 22 | nusaybin
# Processing Record 1 of Set 23 | boo
# Processing Record 2 of Set 23 | takoradi
# Processing Record 3 of Set 23 | saint george
# Processing Record 4 of Set 23 | caucaia
# Processing Record 5 of Set 23 | juba
# Processing Record 6 of Set 23 | kidal
# Processing Record 7 of Set 23 | kaka
# Processing Record 8 of Set 23 | oksfjord
# Processing Record 9 of Set 23 | zhanaozen
# Processing Record 10 of Set 23 | maumere
# Processing Record 11 of Set 23 | joniskis
# Processing Record 12 of Set 23 | aste
# Processing Record 13 of Set 23 | pisz
# Processing Record 14 of Set 23 | deputatskiy
# Processing Record 15 of Set 23 | qingan
# City not found. Skipping...
# Processing Record 16 of Set 23 | belyy yar
# Processing Record 17 of Set 23 | tura
# Processing Record 18 of Set 23 | sao filipe
# Processing Record 19 of Set 23 | willmar
# Processing Record 20 of Set 23 | nanakuli
# Processing Record 21 of Set 23 | satkhira
# Processing Record 22 of Set 23 | daru
# Processing Record 23 of Set 23 | sao joao da barra
# Processing Record 24 of Set 23 | santa maria
# Processing Record 25 of Set 23 | ondjiva
# Processing Record 26 of Set 23 | thayetmyo
# Processing Record 27 of Set 23 | raahe
# Processing Record 28 of Set 23 | kichera
# Processing Record 29 of Set 23 | preobrazheniye
# Processing Record 30 of Set 23 | henties bay
# Processing Record 31 of Set 23 | sola
# Processing Record 32 of Set 23 | san ramon
# Processing Record 33 of Set 23 | ossora
# Processing Record 34 of Set 23 | wanning
# Processing Record 35 of Set 23 | kudahuvadhoo
# Processing Record 36 of Set 23 | fairbanks
# Processing Record 37 of Set 23 | lososina
# Processing Record 38 of Set 23 | san isidro
# Processing Record 39 of Set 23 | orlik
# Processing Record 40 of Set 23 | hervey bay
# Processing Record 41 of Set 23 | verkhnevilyuysk
# Processing Record 42 of Set 23 | micheweni
# Processing Record 43 of Set 23 | semey
# Processing Record 44 of Set 23 | tongren
# Processing Record 45 of Set 23 | beloha
# Processing Record 46 of Set 23 | cowra
# Processing Record 47 of Set 23 | milingimbi
# City not found. Skipping...
# Processing Record 48 of Set 23 | havoysund
# Processing Record 49 of Set 23 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 23 | la sarre
# Processing Record 1 of Set 24 | roma
# Processing Record 2 of Set 24 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 24 | bam
# Processing Record 4 of Set 24 | tual
# Processing Record 5 of Set 24 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 24 | siyabuswa
# Processing Record 7 of Set 24 | acaponeta
# Processing Record 8 of Set 24 | havre-saint-pierre
# Processing Record 9 of Set 24 | beyneu
# Processing Record 10 of Set 24 | momcilgrad
# City not found. Skipping...
# Processing Record 11 of Set 24 | gondanglegi
# Processing Record 12 of Set 24 | bossembele
# City not found. Skipping...
# Processing Record 13 of Set 24 | gboko
# Processing Record 14 of Set 24 | vangaindrano
# Processing Record 15 of Set 24 | gagarin
# Processing Record 16 of Set 24 | salinopolis
# Processing Record 17 of Set 24 | kindia
# Processing Record 18 of Set 24 | salym
# Processing Record 19 of Set 24 | kupang
# Processing Record 20 of Set 24 | kokkola
# Processing Record 21 of Set 24 | ruwi
# Processing Record 22 of Set 24 | tazovskiy
# Processing Record 23 of Set 24 | ibadan
# Processing Record 24 of Set 24 | buloh kasap
# Processing Record 25 of Set 24 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 24 | faya
# Processing Record 27 of Set 24 | machali
# Processing Record 28 of Set 24 | nyimba
# Processing Record 29 of Set 24 | bien hoa
# Processing Record 30 of Set 24 | tocopilla
# Processing Record 31 of Set 24 | jalu
# Processing Record 32 of Set 24 | freeport
# Processing Record 33 of Set 24 | elban
# Processing Record 34 of Set 24 | mackay
# Processing Record 35 of Set 24 | moa
# Processing Record 36 of Set 24 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 24 | paamiut
# Processing Record 38 of Set 24 | nhulunbuy
# Processing Record 39 of Set 24 | kokoda
# Processing Record 40 of Set 24 | kijang
# Processing Record 41 of Set 24 | tigre
# Processing Record 42 of Set 24 | inhambane
# Processing Record 43 of Set 24 | cody
# Processing Record 44 of Set 24 | camapua
# Processing Record 45 of Set 24 | kota kinabalu
# Processing Record 46 of Set 24 | playa del carmen
# Processing Record 47 of Set 24 | saint-pierre
# Processing Record 48 of Set 24 | broken hill
# Processing Record 49 of Set 24 | san ignacio de sabaneta
# City not found. Skipping...
# Processing Record 50 of Set 24 | bontang
# Processing Record 1 of Set 25 | clevelandia
# Processing Record 2 of Set 25 | rabo de peixe
# Processing Record 3 of Set 25 | sakaiminato
# Processing Record 4 of Set 25 | amapa
# Processing Record 5 of Set 25 | solsvik
# City not found. Skipping...
# Processing Record 6 of Set 25 | gallipoli
# Processing Record 7 of Set 25 | lazaro cardenas
# Processing Record 8 of Set 25 | atasu
# Processing Record 9 of Set 25 | luanda
# Processing Record 10 of Set 25 | altay
# Processing Record 11 of Set 25 | matagami
# Processing Record 12 of Set 25 | makokou
# -------------------------
# Data Retrieval Complete.
# -------------------------

# %%
len(city_data)
# Out:
# 559

# %%
# Convert the array of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Tuatapere -46.1333  167.6833     51.82        86          92        9.37
# 1  Yellowknife  62.4560 -114.3525      5.41        89          75        5.75
# 2        Alofi -19.0595 -169.9187     81.68        76           6       15.19
# 3       Manado   1.4870  124.8455     75.97        94          20        1.14
# 4   Oranjemund -28.5500   16.4333     64.62        91          38       15.64
#
#   Country                 Date
# 0      NZ  2022-01-26 19:03:16
# 1      CA  2022-01-26 19:00:53
# 2      NU  2022-01-26 19:03:16
# 3      ID  2022-01-26 19:03:17
# 4      NA  2022-01-26 19:03:17

# %%
# reorder the columns so it's easier to read
new_column_order = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0    Tuatapere      NZ  2022-01-26 19:03:16 -46.1333  167.6833     51.82
# 1  Yellowknife      CA  2022-01-26 19:00:53  62.4560 -114.3525      5.41
# 2        Alofi      NU  2022-01-26 19:03:16 -19.0595 -169.9187     81.68
# 3       Manado      ID  2022-01-26 19:03:17   1.4870  124.8455     75.97
# 4   Oranjemund      NA  2022-01-26 19:03:17 -28.5500   16.4333     64.62
#
#    Humidity  Cloudiness  Wind Speed
# 0        86          92        9.37
# 1        89          75        5.75
# 2        76           6       15.19
# 3        94          20        1.14
# 4        91          38       15.64

# %%
# Create output file (CSV)
output_data_file = "weather_data/cities.csv"
# Export the city_data_df into a CSV
city_data_df.to_csv(output_data_file, index_label = "City_ID")
